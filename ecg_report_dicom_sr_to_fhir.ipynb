# %%
from typing import List, Optional, Dict
import uuid
import pydicom
from fhir.resources.patient import Patient
from fhir.resources.observation import Observation
from fhir.resources.diagnosticreport import DiagnosticReport
from fhir.resources.codeableconcept import CodeableConcept
from fhir.resources.coding import Coding
from fhir.resources.reference import Reference
from datetime import datetime
import highdicom as hd

# %%
def recursive_search_for_coded_concept(
        ds: pydicom.Dataset, 
        coded_concept: hd.sr.CodedConcept
) -> List[pydicom.Dataset]:
    return_items = []
    for content_item in ds.ContentSequence:
        if hasattr(content_item, 'ConceptNameCodeSequence'):
            concept = content_item.ConceptNameCodeSequence[0]

            concept = hd.sr.CodedConcept(
                value=concept.CodeValue,
                scheme_designator=concept.CodingSchemeDesignator,
                meaning=concept.CodeMeaning
            )

            if concept == coded_concept:
                return_items.append(content_item)
        
        if hasattr(content_item, 'ContentSequence'):
            _return_items = recursive_search_for_coded_concept(content_item, coded_concept=coded_concept)
            return_items += _return_items
    return return_items


def create_observation_resource(
        code_value: str, 
        code_system: str, 
        code_display: str, 
        patient_id: str,
        value_quantity: Optional[Dict] = None
) -> Observation:
    return Observation(
        id=str(uuid.uuid4()),
        status="final",
        code=CodeableConcept(
            coding=[Coding(
                system=code_system,
                code=code_value,
                display=code_display
            )]
        ),
        subject=Reference(reference=f"Patient/{patient_id}"),
        effectiveDateTime=datetime.now().isoformat(),
        valueQuantity=value_quantity
    )


def string_observation(
        ds: pydicom.Dataset, 
        coded_concept: hd.sr.CodedConcept
) -> List[Observation]:
    items = recursive_search_for_coded_concept(ds, coded_concept)
    observations = []
    for item in items:
        item = item.ConceptCodeSequence[0]
        observation = create_observation_resource(
            code_value=item.CodeValue,
            code_system=item.CodingSchemeDesignator,
            code_display=item.CodeMeaning,
            patient_id=ds.PatientID
        )
        observations.append(observation)

    return observations


def numeric_measurements(
        ds: pydicom.Dataset, 
        coded_concept: hd.sr.CodedConcept
) -> List[Observation]:
    items = recursive_search_for_coded_concept(ds, coded_concept)
    observations = []
    for item in items:
        measurement = item.MeasuredValueSequence[0].NumericValue
        unit = item.MeasuredValueSequence[0].MeasurementUnitsCodeSequence[0]
        value_quantity = {
            "value": float(measurement),
            "unit": unit.CodeMeaning,
            "system": unit.CodingSchemeDesignator,
            "code": unit.CodeMeaning
        }
        observation = create_observation_resource(
            code_value=coded_concept.CodeValue,
            code_system=coded_concept.CodingSchemeDesignator,
            code_display=coded_concept.CodeMeaning,
            patient_id=ds.PatientID,
            value_quantity=value_quantity
        )
        observations.append(observation)

    return observations

# %%
ds = pydicom.dcmread('example_ecg_sr.dcm')
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 214
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Comprehensive SR Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.10.511.3.56431750657457273228940717842343408
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.9.7433.1.1
# (0002, 0013) Implementation Version Name         SH: 'highdicom0.21.1'
# -------------------------------------------------
# (0008, 0016) SOP Class UID                       UI: Comprehensive SR Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.10.511.3.56431750657457273228940717842343408
# (0008, 0020) Study Date                          DA: '20240101'
# (0008, 0023) Content Date                        DA: '20240902'
# (0008, 0030) Study Time                          TM: '113730'
# (0008, 0033) Content Time                        TM: '164439.683942'
# (0008, 0050) Accession Number                    SH: '1'
# (0008, 0060) Modality                            CS: 'SR'
# (0008, 0070) Manufacturer                        LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Resting 12-lead ECG'
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1111)  Referenced Performed Procedure Step Sequence  0 item(s) ----
# (0010, 0010) Patient's Name                      PN: 'Mustermann^Max'
# (0010, 0020) Patient ID                          LO: '0123456789'
# (0010, 0030) Patient's Birth Date                DA: '19640101'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '060Y'
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 2160) Ethnic Group                        SH: ''
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.8.498.12864580824097706834393059849272204080
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.10.511.3.10981877544674571710873141369813120
# (0020, 0010) Study ID                            SH: '123456789'
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0038, 0010) Admission ID                        LO: ''
# (0040, a040) Value Type                          CS: 'CONTAINER'
# (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '11524-0'
#    (0008, 0102) Coding Scheme Designator            SH: 'LN'
#    (0008, 0104) Code Meaning                        LO: 'ECG Report'
#    ---------
# (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
# (0040, a372)  Performed Procedure Code Sequence  0 item(s) ----
# (0040, a385)  Pertinent Other Evidence Sequence  1 item(s) ----
#    (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#       (0008, 1199)  Referenced SOP Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: 12-lead ECG Waveform Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.2.826.0.1.3680043.8.498.89623170437663723329382978340499119689
#          ---------
#       (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.8.498.21257606409783556160725868414407030543
#       ---------
#    (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.8.498.12864580824097706834393059849272204080
#    ---------
# (0040, a491) Completion Flag                     CS: 'PARTIAL'
# (0040, a493) Verification Flag                   CS: 'UNVERIFIED'
# (0040, a496) Preliminary Flag                    CS: 'PRELIMINARY'
# (0040, a504)  Content Template Sequence  1 item(s) ----
#    (0008, 0105) Mapping Resource                    CS: 'DCMR'
#    (0040, db00) Template Identifier                 CS: '3700'
#    ---------
# (0040, a730)  Content Sequence  9 item(s) ----
#    (0040, a010) Relationship Type                   CS: 'HAS CONCEPT MOD'
#    (0040, a040) Value Type                          CS: 'CODE'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '121049'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Language of Content Item and Descendants'
#       ---------
#    (0040, a168)  Concept Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'de-DE'
#       (0008, 0102) Coding Scheme Designator            SH: 'RFC5646'
#       (0008, 0104) Code Meaning                        LO: 'German (Germany)'
#       ---------
#    ---------
#    (0040, a010) Relationship Type                   CS: 'HAS OBS CONTEXT'
#    (0040, a040) Value Type                          CS: 'CODE'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '121005'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Observer Type'
#       ---------
#    (0040, a168)  Concept Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '121006'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Person'
#       ---------
#    ---------
#    (0040, a010) Relationship Type                   CS: 'HAS OBS CONTEXT'
#    (0040, a040) Value Type                          CS: 'PNAME'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '121008'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Person Observer Name'
#       ---------
#    (0040, a123) Person Name                         PN: 'Mustermann^Max'
#    ---------
#    (0040, a010) Relationship Type                   CS: 'HAS OBS CONTEXT'
#    (0040, a040) Value Type                          CS: 'CODE'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '121005'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Observer Type'
#       ---------
#    (0040, a168)  Concept Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '121007'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Device'
#       ---------
#    ---------
#    (0040, a010) Relationship Type                   CS: 'HAS OBS CONTEXT'
#    (0040, a040) Value Type                          CS: 'UIDREF'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '121012'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Device Observer UID'
#       ---------
#    (0040, a124) UID                                 UI: 1.2.826.0.1.3680043.10.511.3.45142667692843894368719330329688917
#    ---------
#    (0040, a010) Relationship Type                   CS: 'CONTAINS'
#    (0040, a040) Value Type                          CS: 'CONTAINER'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '55111-9'
#       (0008, 0102) Coding Scheme Designator            SH: 'LN'
#       (0008, 0104) Code Meaning                        LO: 'Current Procedure Descriptions'
#       ---------
#    (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#    (0040, a504)  Content Template Sequence  1 item(s) ----
#       (0008, 0105) Mapping Resource                    CS: 'DCMR'
#       (0040, db00) Template Identifier                 CS: '3708'
#       ---------
#    (0040, a730)  Content Sequence  5 item(s) ----
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'DATETIME'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '122146'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Procedure DateTime'
#          ---------
#       (0040, a120) DateTime                            DT: '20240902164439.548779'
#       ---------
#       (0008, 1199)  Referenced SOP Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: 12-lead ECG Waveform Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 1.2.826.0.1.3680043.8.498.89623170437663723329382978340499119689
#          ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'WAVEFORM'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: 'C0018799'
#          (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#          (0008, 0104) Code Meaning                        LO: 'Electrocardiogram'
#          ---------
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'CODE'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '10:11345'
#          (0008, 0102) Coding Scheme Designator            SH: 'MDC'
#          (0008, 0104) Code Meaning                        LO: 'Lead System'
#          ---------
#       (0040, a168)  Concept Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '10:11265'
#          (0008, 0102) Coding Scheme Designator            SH: 'MDC'
#          (0008, 0104) Code Meaning                        LO: 'Standard 12-lead positions, electrodes placed individually'
#          ---------
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'TEXT'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '122142'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Acquisition Device Type'
#          ---------
#       (0040, a160) Text Value                          UT: Array of 41 elements
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'TEXT'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121122'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Equipment Identification'
#          ---------
#       (0040, a160) Text Value                          UT: Array of 24 elements
#       ---------
#    ---------
#    (0040, a010) Relationship Type                   CS: 'CONTAINS'
#    (0040, a040) Value Type                          CS: 'CONTAINER'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '55111-9'
#       (0008, 0102) Coding Scheme Designator            SH: 'LN'
#       (0008, 0104) Code Meaning                        LO: 'Current Procedure Descriptions'
#       ---------
#    (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#    (0040, a504)  Content Template Sequence  1 item(s) ----
#       (0008, 0105) Mapping Resource                    CS: 'DCMR'
#       (0040, db00) Template Identifier                 CS: '3708'
#       ---------
#    (0040, a730)  Content Sequence  1 item(s) ----
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'CONTAINER'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '122158'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'ECG Global Measurements'
#          ---------
#       (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#       (0040, a504)  Content Template Sequence  1 item(s) ----
#          (0008, 0105) Mapping Resource                    CS: 'DCMR'
#          (0040, db00) Template Identifier                 CS: '3713'
#          ---------
#       (0040, a730)  Content Sequence  5 item(s) ----
#          (0040, a010) Relationship Type                   CS: 'CONTAINS'
#          (0040, a040) Value Type                          CS: 'NUM'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '2:16016'
#             (0008, 0102) Coding Scheme Designator            SH: 'MDC'
#             (0008, 0104) Code Meaning                        LO: 'Ventricular Heart Rate'
#             ---------
#          (0040, a300)  Measured Value Sequence  1 item(s) ----
#             (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '1'
#                (0008, 0102) Coding Scheme Designator            SH: 'UCUM'
#                (0008, 0104) Code Meaning                        LO: 'no units'
#                ---------
#             (0040, a161) Floating Point Value                FD: 75.0
#             (0040, a30a) Numeric Value                       DS: '75.0'
#             ---------
#          ---------
#          (0040, a010) Relationship Type                   CS: 'CONTAINS'
#          (0040, a040) Value Type                          CS: 'NUM'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '2:16160'
#             (0008, 0102) Coding Scheme Designator            SH: 'MDC'
#             (0008, 0104) Code Meaning                        LO: 'QT interval global'
#             ---------
#          (0040, a300)  Measured Value Sequence  1 item(s) ----
#             (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: 'ms'
#                (0008, 0102) Coding Scheme Designator            SH: 'UCUM'
#                (0008, 0104) Code Meaning                        LO: 'millisecond'
#                ---------
#             (0040, a161) Floating Point Value                FD: 400.0
#             (0040, a30a) Numeric Value                       DS: '400.0'
#             ---------
#          ---------
#          (0040, a010) Relationship Type                   CS: 'CONTAINS'
#          (0040, a040) Value Type                          CS: 'NUM'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '2:15872'
#             (0008, 0102) Coding Scheme Designator            SH: 'MDC'
#             (0008, 0104) Code Meaning                        LO: 'PR interval global'
#             ---------
#          (0040, a300)  Measured Value Sequence  1 item(s) ----
#             (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: 'ms'
#                (0008, 0102) Coding Scheme Designator            SH: 'UCUM'
#                (0008, 0104) Code Meaning                        LO: 'millisecond'
#                ---------
#             (0040, a161) Floating Point Value                FD: 140.0
#             (0040, a30a) Numeric Value                       DS: '140.0'
#             ---------
#          ---------
#          (0040, a010) Relationship Type                   CS: 'CONTAINS'
#          (0040, a040) Value Type                          CS: 'NUM'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '2:16156'
#             (0008, 0102) Coding Scheme Designator            SH: 'MDC'
#             (0008, 0104) Code Meaning                        LO: 'QRS duration global'
#             ---------
#          (0040, a300)  Measured Value Sequence  1 item(s) ----
#             (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: 'ms'
#                (0008, 0102) Coding Scheme Designator            SH: 'UCUM'
#                (0008, 0104) Code Meaning                        LO: 'millisecond'
#                ---------
#             (0040, a161) Floating Point Value                FD: 100.0
#             (0040, a30a) Numeric Value                       DS: '100.0'
#             ---------
#          ---------
#          (0040, a010) Relationship Type                   CS: 'CONTAINS'
#          (0040, a040) Value Type                          CS: 'NUM'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '2:16168'
#             (0008, 0102) Coding Scheme Designator            SH: 'MDC'
#             (0008, 0104) Code Meaning                        LO: 'RR interval global'
#             ---------
#          (0040, a300)  Measured Value Sequence  1 item(s) ----
#             (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: 'ms'
#                (0008, 0102) Coding Scheme Designator            SH: 'UCUM'
#                (0008, 0104) Code Meaning                        LO: 'millisecond'
#                ---------
#             (0040, a161) Floating Point Value                FD: 800.0
#             (0040, a30a) Numeric Value                       DS: '800.0'
#             ---------
#          ---------
#       ---------
#    ---------
#    (0040, a010) Relationship Type                   CS: 'CONTAINS'
#    (0040, a040) Value Type                          CS: 'CONTAINER'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '11329-0'
#       (0008, 0102) Coding Scheme Designator            SH: 'LN'
#       (0008, 0104) Code Meaning                        LO: 'History'
#       ---------
#    (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#    (0040, a504)  Content Template Sequence  1 item(s) ----
#       (0008, 0105) Mapping Resource                    CS: 'DCMR'
#       (0040, db00) Template Identifier                 CS: '3802'
#       ---------
#    (0040, a730)  Content Sequence  4 item(s) ----
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'CONTAINER'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '11450-4'
#          (0008, 0102) Coding Scheme Designator            SH: 'LN'
#          (0008, 0104) Code Meaning                        LO: 'Problem List'
#          ---------
#       (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#       (0040, a730)  Content Sequence  2 item(s) ----
#          (0040, a010) Relationship Type                   CS: 'CONTAINS'
#          (0040, a040) Value Type                          CS: 'CONTAINER'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121430'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Concern'
#             ---------
#          (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#          (0040, a504)  Content Template Sequence  1 item(s) ----
#             (0008, 0105) Mapping Resource                    CS: 'DCMR'
#             (0040, db00) Template Identifier                 CS: '3829'
#             ---------
#          (0040, a730)  Content Sequence  2 item(s) ----
#             (0040, a010) Relationship Type                   CS: 'CONTAINS'
#             (0040, a040) Value Type                          CS: 'CODE'
#             (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '418799008'
#                (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#                (0008, 0104) Code Meaning                        LO: 'Finding reported by patient/informant'
#                ---------
#             (0040, a168)  Concept Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '400047006'
#                (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#                (0008, 0104) Code Meaning                        LO: 'Peripheral vascular disease'
#                ---------
#             ---------
#             (0040, a010) Relationship Type                   CS: 'CONTAINS'
#             (0040, a040) Value Type                          CS: 'DATETIME'
#             (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '121431'
#                (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#                (0008, 0104) Code Meaning                        LO: 'DateTime Concern Noted'
#                ---------
#             (0040, a120) DateTime                            DT: '20240902164439.583187'
#             ---------
#          ---------
#          (0040, a010) Relationship Type                   CS: 'CONTAINS'
#          (0040, a040) Value Type                          CS: 'CONTAINER'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121430'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Concern'
#             ---------
#          (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#          (0040, a504)  Content Template Sequence  1 item(s) ----
#             (0008, 0105) Mapping Resource                    CS: 'DCMR'
#             (0040, db00) Template Identifier                 CS: '3829'
#             ---------
#          (0040, a730)  Content Sequence  3 item(s) ----
#             (0040, a010) Relationship Type                   CS: 'CONTAINS'
#             (0040, a040) Value Type                          CS: 'CODE'
#             (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '418799008'
#                (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#                (0008, 0104) Code Meaning                        LO: 'Finding reported by patient/informant'
#                ---------
#             (0040, a168)  Concept Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '399211009'
#                (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#                (0008, 0104) Code Meaning                        LO: 'History of myocardidal infarction'
#                ---------
#             ---------
#             (0040, a010) Relationship Type                   CS: 'CONTAINS'
#             (0040, a040) Value Type                          CS: 'DATETIME'
#             (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '121431'
#                (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#                (0008, 0104) Code Meaning                        LO: 'DateTime Concern Noted'
#                ---------
#             (0040, a120) DateTime                            DT: '20240902164439.582513'
#             ---------
#             (0040, a010) Relationship Type                   CS: 'CONTAINS'
#             (0040, a040) Value Type                          CS: 'CODE'
#             (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '277132007'
#                (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#                (0008, 0104) Code Meaning                        LO: 'Therapy'
#                ---------
#             (0040, a168)  Concept Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '232717009'
#                (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#                (0008, 0104) Code Meaning                        LO: 'Coronary artery bypass graft'
#                ---------
#             ---------
#          ---------
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'CONTAINER'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '29762-2'
#          (0008, 0102) Coding Scheme Designator            SH: 'LN'
#          (0008, 0104) Code Meaning                        LO: 'Social History'
#          ---------
#       (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#       (0040, a730)  Content Sequence  1 item(s) ----
#          (0040, a010) Relationship Type                   CS: 'CONTAINS'
#          (0040, a040) Value Type                          CS: 'CODE'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '365981007'
#             (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#             (0008, 0104) Code Meaning                        LO: 'Tobacco Smoking Behavior'
#             ---------
#          (0040, a168)  Concept Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '77176002'
#             (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#             (0008, 0104) Code Meaning                        LO: 'Current Smoker'
#             ---------
#          ---------
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'CONTAINER'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '10167-5'
#          (0008, 0102) Coding Scheme Designator            SH: 'LN'
#          (0008, 0104) Code Meaning                        LO: 'Past Surgical History'
#          ---------
#       (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#       (0040, a730)  Content Sequence  2 item(s) ----
#          (0040, a010) Relationship Type                   CS: 'HAS CONCEPT MOD'
#          (0040, a040) Value Type                          CS: 'CODE'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '387713003'
#             (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#             (0008, 0104) Code Meaning                        LO: 'Surgical Procedure'
#             ---------
#          (0040, a168)  Concept Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '232717009'
#             (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#             (0008, 0104) Code Meaning                        LO: 'Coronary artery bypass graft'
#             ---------
#          ---------
#          (0040, a010) Relationship Type                   CS: 'HAS CONCEPT MOD'
#          (0040, a040) Value Type                          CS: 'CODE'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '387713003'
#             (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#             (0008, 0104) Code Meaning                        LO: 'Surgical Procedure'
#             ---------
#          (0040, a168)  Concept Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '307280005'
#             (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#             (0008, 0104) Code Meaning                        LO: 'Implantation of cardiac pacemaker'
#             ---------
#          ---------
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'CONTAINER'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '30954-2'
#          (0008, 0102) Coding Scheme Designator            SH: 'LN'
#          (0008, 0104) Code Meaning                        LO: 'Relevant Diagnostic Tests and/or Laboratory Data'
#          ---------
#       (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#       (0040, a730)  Content Sequence  2 item(s) ----
#          (0040, a010) Relationship Type                   CS: 'HAS PROPERTIES'
#          (0040, a040) Value Type                          CS: 'NUM'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '2086-7'
#             (0008, 0102) Coding Scheme Designator            SH: 'LN'
#             (0008, 0104) Code Meaning                        LO: 'Cholesterol in HDL'
#             ---------
#          (0040, a300)  Measured Value Sequence  1 item(s) ----
#             (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '1'
#                (0008, 0102) Coding Scheme Designator            SH: 'UCUM'
#                (0008, 0104) Code Meaning                        LO: 'no units'
#                ---------
#             (0040, a161) Floating Point Value                FD: 75.0
#             (0040, a30a) Numeric Value                       DS: '75.0'
#             ---------
#          ---------
#          (0040, a010) Relationship Type                   CS: 'HAS PROPERTIES'
#          (0040, a040) Value Type                          CS: 'NUM'
#          (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '2089-1'
#             (0008, 0102) Coding Scheme Designator            SH: 'LN'
#             (0008, 0104) Code Meaning                        LO: 'Cholesterol in LDL'
#             ---------
#          (0040, a300)  Measured Value Sequence  1 item(s) ----
#             (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#                (0008, 0100) Code Value                          SH: '1'
#                (0008, 0102) Coding Scheme Designator            SH: 'UCUM'
#                (0008, 0104) Code Meaning                        LO: 'no units'
#                ---------
#             (0040, a161) Floating Point Value                FD: 160.0
#             (0040, a30a) Numeric Value                       DS: '160.0'
#             ---------
#          ---------
#       ---------
#    ---------
#    (0040, a010) Relationship Type                   CS: 'CONTAINS'
#    (0040, a040) Value Type                          CS: 'CONTAINER'
#    (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '121118'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Patient Characteristics'
#       ---------
#    (0040, a050) Continuity Of Content               CS: 'CONTINUOUS'
#    (0040, a504)  Content Template Sequence  1 item(s) ----
#       (0008, 0105) Mapping Resource                    CS: 'DCMR'
#       (0040, db00) Template Identifier                 CS: '3704'
#       ---------
#    (0040, a730)  Content Sequence  6 item(s) ----
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'NUM'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121033'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Subject Age'
#          ---------
#       (0040, a300)  Measured Value Sequence  1 item(s) ----
#          (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '7456'
#             (0008, 0102) Coding Scheme Designator            SH: 'CID'
#             (0008, 0104) Code Meaning                        LO: 'Age Unit'
#             ---------
#          (0040, a30a) Numeric Value                       DS: '60.0'
#          ---------
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'TEXT'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121032'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Subject Sex'
#          ---------
#       (0040, a160) Text Value                          UT: 'M'
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'NUM'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '271649006'
#          (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#          (0008, 0104) Code Meaning                        LO: 'Systolic blood pressure (observable entity)'
#          ---------
#       (0040, a300)  Measured Value Sequence  1 item(s) ----
#          (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '3500'
#             (0008, 0102) Coding Scheme Designator            SH: 'CID'
#             (0008, 0104) Code Meaning                        LO: 'Pressure Unit'
#             ---------
#          (0040, a161) Floating Point Value                FD: 160.0
#          (0040, a30a) Numeric Value                       DS: '160.0'
#          ---------
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'NUM'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '271650006'
#          (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#          (0008, 0104) Code Meaning                        LO: 'Diastolic blood pressure (observable entity)'
#          ---------
#       (0040, a300)  Measured Value Sequence  1 item(s) ----
#          (0040, 08ea)  Measurement Units Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '3500'
#             (0008, 0102) Coding Scheme Designator            SH: 'CID'
#             (0008, 0104) Code Meaning                        LO: 'Pressure Unit'
#             ---------
#          (0040, a161) Floating Point Value                FD: 100.0
#          (0040, a30a) Numeric Value                       DS: '100.0'
#          ---------
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'CODE'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '109054'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Patient State'
#          ---------
#       (0040, a168)  Concept Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '128975004'
#          (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#          (0008, 0104) Code Meaning                        LO: 'Resting state'
#          ---------
#       ---------
#       (0040, a010) Relationship Type                   CS: 'CONTAINS'
#       (0040, a040) Value Type                          CS: 'CODE'
#       (0040, a043)  Concept Name Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '441509002'
#          (0008, 0102) Coding Scheme Designator            SH: 'SCT'
#          (0008, 0104) Code Meaning                        LO: 'Pacemaker in situ'
#          ---------
#       (0040, a168)  Concept Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: 'D'
#          (0008, 0102) Coding Scheme Designator            SH: 'NBG'
#          (0008, 0104) Code Meaning                        LO: 'Dual (A+V)'
#          ---------
#       ---------
#    ---------

# %%
# Convert DICOM Patient Information to FHIR Patient Resource
patient = Patient(
    id=ds.PatientID,
    name=[{
        "family": ds.PatientName.family_name,
        "given": ds.PatientName.given_name.split('^')
    }],
    birthDate=ds.PatientBirthDate,
    gender="male" if ds.PatientSex == "M" else "female"
)

# %%
dbp_code = hd.sr.CodedConcept(
    value='271650006',
    scheme_designator='SCT',
    meaning='Diastolic blood pressure (observable entity)'
)
dbp_observations = numeric_measurements(ds, dbp_code)

sbp_code = hd.sr.CodedConcept(
    value="271649006",
    scheme_designator='SCT',
    meaning="Systolic blood pressure (observable entity)"
)
sbp_oberservations = numeric_measurements(ds, sbp_code)

# %%
surgical_procedure_code = hd.sr.CodedConcept(
    value='387713003', 
    scheme_designator='SCT',
    meaning='Surgical Procedure'
)

surgical_procedure_observations = string_observation(ds, surgical_procedure_code)

# %%
observations = [
    *dbp_observations, *sbp_oberservations, *surgical_procedure_observations
]

# %%
# # Convert DICOM SR Document to FHIR DiagnosticReport
diagnostic_report = DiagnosticReport(
    status="final",
    code=CodeableConcept(
        coding=[Coding(
            system="http://loinc.org",
            code="11524-0",
            display="ECG Report"
        )]
    ),
    subject=Reference(reference=f"Patient/{ds.PatientID}"),
    effectiveDateTime=datetime.now().isoformat(),
    result=[Reference(reference=f"Observation/{obs.id}") for obs in observations]
)

# %%
diagnostic_report.dict()
# Out:
# OrderedDict([('resourceType', 'DiagnosticReport'),
#              ('status', 'final'),
#              ('code',
#               OrderedDict([('coding',
#                             [OrderedDict([('system', 'http://loinc.org'),
#                                           ('code', '11524-0'),
#                                           ('display', 'ECG Report')])])])),
#              ('subject', OrderedDict([('reference', 'Patient/0123456789')])),
#              ('effectiveDateTime',
#               datetime.datetime(2024, 9, 3, 17, 58, 38, 238806)),
#              ('result',
#               [OrderedDict([('reference',
#                              'Observation/2e5dd4ea-e4b2-4301-88f2-74a430c3c5e3')]),
#                OrderedDict([('reference',
#                              'Observation/d5dca584-85f7-4462-af47-7d0e3a968fc8')]),
#                OrderedDict([('reference',
#                              'Observation/9347876e-0ba2-4bdb-b547-0386bc1fe714')]),
#                OrderedDict([('reference',
#                              'Observation/625fe33e-7c5b-4aca-ad98-f9e4280b8dbf')])])])
